# %%
import pandas as pd
import requests

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=237af7c9dea012a4a6ec3f40e5f87c2a&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
response= requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=237af7c9dea012a4a6ec3f40e5f87c2a&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 171.576,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.708,
#    'vote_count': 27739},
#   {'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 171.576,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.708,
#   'vote_count': 27739},
#  {'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]     389
# 5   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]     129
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 7   False  /oOv2oUXcAaNXakRqUPxYq5lJURz.jpg  [18, 28, 80, 53]     155
# 8   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]     497
# 9   False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg      [35, 53, 18]  496243
# 10  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# 11  False  /8x9iKH8kWA0zdkgNdpAew7OstYe.jpg   [16, 10749, 18]  372058
# ...

# %%
pd.DataFrame(response.json()['results']).head(4)
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     171.576
# 1  Spanning the years 1945 to 1955, a chronicle o...     171.080
# 2  In the continuing saga of the Corleone crime f...      90.867
# 3  The true story of how businessman Oskar Schind...     107.578
#
# ...

# %%
pd.DataFrame(response.json()['results'])[['genre_ids','overview','title']]
# Out:
#            genre_ids                                           overview  \
# 0           [18, 80]  Imprisoned in the 1940s for the double murder ...
# 1           [18, 80]  Spanning the years 1945 to 1955, a chronicle o...
# 2           [18, 80]  In the continuing saga of the Corleone crime f...
# 3    [18, 36, 10752]  The true story of how businessman Oskar Schind...
# 4               [18]  The defense and the prosecution have rested an...
# 5    [16, 10751, 14]  A young girl, Chihiro, becomes trapped in a st...
# 6    [35, 18, 10749]  Raj is a rich, carefree, happy-go-lucky second...
# 7   [18, 28, 80, 53]  Batman raises the stakes in his war on crime. ...
# 8       [14, 18, 80]  A supernatural tale set on death row in a Sout...
# 9       [35, 53, 18]  All unemployed, Ki-taek's family takes peculia...
# 10          [53, 80]  A burger-loving hit man, his philosophical par...
# 11   [16, 10749, 18]  High schoolers Mitsuha and Taki are complete s...
# ...

# %%
df=pd.DataFrame(response.json()['results'])[['genre_ids','overview','title']]

# %%
df.head(4)
# Out:
#          genre_ids                                           overview  \
# 0         [18, 80]  Imprisoned in the 1940s for the double murder ...
# 1         [18, 80]  Spanning the years 1945 to 1955, a chronicle o...
# 2         [18, 80]  In the continuing saga of the Corleone crime f...
# 3  [18, 36, 10752]  The true story of how businessman Oskar Schind...
#
#                       title
# 0  The Shawshank Redemption
# 1             The Godfather
# 2     The Godfather Part II
# 3          Schindler's List

# %%
requests.get('http://api.themoviedb.org/3/genre/movie/list?api_key=237af7c9dea012a4a6ec3f40e5f87c2a&language=en-US')
# Out:
# <Response [200]>

# %%
response=requests.get('http://api.themoviedb.org/3/genre/movie/list?api_key=237af7c9dea012a4a6ec3f40e5f87c2a&language=en-US')

# %%
response.json()
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 36, 'name': 'History'},
#   {'id': 27, 'name': 'Horror'},
#   {'id': 10402, 'name': 'Music'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 10770, 'name': 'TV Movie'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 10752, 'name': 'War'},
#   {'id': 37, 'name': 'Western'}]}

# %%
df= pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 499):
    response= requests.get('http://api.themoviedb.org/3/movie/top_rated?api_key=237af7c9dea012a4a6ec3f40e5f87c2a&language=en-US&page={}'.format(i))
    temp_df= pd.DataFrame(response.json()['results'])[['genre_ids','overview','title']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (12300, 3)

# %%
df.to_csv('movies_without_genre.csv')
